# %% [markdown]
# # Enumerate
# When we want to loop through an object and have

# %%
# %ls ./../spectra
# Out:
# 17-03-04_DEIMOS_U058.html
# Eku1.30Zm0.66T14.0000_iTp0.00_baseFe_linear_FWHM_variable.fits
# FCcurve_600line.txt
# MILES_SSP_14Gyr_n0.66.tar.gz
# VCC1075.fits
# VCC1076.fits
# VCC1079.fits
# VCC1396.fits
# VCC1407.fits
# VCC1420.fits
# VCC1488.fits
# VCC1491.fits
# VCC1499.fits
# VCC1509.fits
# VCC1523.fits
# VCC1539.fits
# VCC1545.fits
# VCC1561.fits
# VCC1563.fits
# VCC1809.fits
# VCC1828.fits
# VCC1861.fits
# VCC1870.fits
# VCC1871.fits
# VCC1879.fits
# spec1d.vdgc1.000.alg42.fits
# spec1d.vdgc1.001.alg115.fits
# spec1d.vdgc1.002.alg140.fits
# spec1d.vdgc1.003.alg164.fits
# spec1d.vdgc1.004.alg177.fits
# spec1d.vdgc1.005.alg191.fits
# spec1d.vdgc1.006.alg194.fits
# spec1d.vdgc1.007.nuc5.fits
# spec1d.vdgc1.008.nuc6.fits
# spec1d.vdgc1.009.nuc7.fits
# spec1d.vdgc1.009.serendip1.fits
# spec1d.vdgc1.010.gcA9.fits
# spec1d.vdgc1.011.gcA10.fits
# spec1d.vdgc1.012.gcA17.fits
# spec1d.vdgc1.013.gcA18.fits
# spec1d.vdgc1.014.gcA19.fits
# spec1d.vdgc1.014.serend1.fits
# ...

# %%
from astropy.io import fits

f = fits.open('./../spectra/spec1d.vugc1.063.GCBO0422.fits.gz')

# %%
f.info()
# Out:
# Filename: ./../spectra/spec1d.vugc1.063.GCBO0422.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  Bxspf-B       1 BinTableHDU    134   1R x 15C   [4096E, 4096E, 4096E, 4096E, 4096E, 4096E, 4096E, 4096I, E, E, E, J, J, 4096E, E]
#   2  Bxspf-R       1 BinTableHDU    134   1R x 15C   [4096E, 4096E, 4096E, 4096E, 4096E, 4096E, 4096E, 4096I, E, E, E, J, J, 4096E, E]
#   3  Horne-B       1 BinTableHDU    143   1R x 15C   [4096E, 4096E, 4096E, 4096E, 4096E, 4096E, 4096E, 4096I, E, E, E, J, J, 4096E, E]
#   4  Horne-R       1 BinTableHDU    143   1R x 15C   [4096E, 4096E, 4096E, 4096E, 4096E, 4096E, 4096E, 4096I, E, E, E, J, J, 4096E, E]

# %%
print(f[1].data['LAMBDA'])
# Out:
# [[4716.1074 4716.716  4717.3237 ... 7294.0854 7294.7305 7295.3755]]
